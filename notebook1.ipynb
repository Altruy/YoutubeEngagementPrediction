# %% [markdown]
# # YouTube Video Popularity Prediction Project

# %% [markdown]
# ## Notebook 1: Data Loading and Storage
#
# In this notebook, we will collect metadata for YouTube videos using the YouTube Data API.
# We will then store the collected data in an S3 bucket.

# %%
# Import necessary libraries
import requests
import pandas as pd
from io import StringIO

# %%
# YouTube Data API v3 key (replace with your own API key)
API_KEY = ''

# Function to search for videos based on keywords
def search_videos_by_keyword(keyword, max_results=500):
    """
    Searches for videos on YouTube based on a given keyword.
    """
    url = f'https://www.googleapis.com/youtube/v3/search?part=snippet&type=video&q={keyword}&maxResults={max_results}&key={API_KEY}'
    response = requests.get(url)
    data = response.json()
    video_ids = [item['id']['videoId'] for item in data.get('items', [])]
    return video_ids

# Function to get video metadata
def get_video_metadata(video_id):
    """
    Fetches metadata for a given YouTube video ID using the YouTube Data API.
    """
    url = f'https://www.googleapis.com/youtube/v3/videos?part=snippet,statistics,contentDetails,status&id={video_id}&key={API_KEY}'
    response = requests.get(url)
    data = response.json()
    if 'items' in data and data['items']:
        item = data['items'][0]
        snippet = item['snippet']
        statistics = item['statistics']
        content_details = item['contentDetails']
        status = item['status']
        return {
            'video_id': video_id,
            'title': snippet['title'],
            'description': snippet['description'],
            'tags': snippet.get('tags', []),
            'published_at': snippet['publishedAt'],
            'channel_id': snippet['channelId'],
            'channel_title': snippet['channelTitle'],
            'category_id': snippet['categoryId'],
            'live_broadcast_content': snippet['liveBroadcastContent'],
            'default_audio_language': snippet.get('defaultAudioLanguage', 'N/A'),
            'view_count': int(statistics.get('viewCount', 0)),
            'like_count': int(statistics.get('likeCount', 0)),
            'dislike_count': int(statistics.get('dislikeCount', 0)),
            'comment_count': int(statistics.get('commentCount', 0)),
            'duration': content_details['duration'],
            'dimension': content_details['dimension'],
            'definition': content_details['definition'],
            'caption': content_details['caption'],
            'licensed_content': content_details['licensedContent'],
            'projection': content_details['projection'],
            'upload_status': status['uploadStatus'],
            'privacy_status': status['privacyStatus'],
            'license': status['license'],
            'embeddable': status['embeddable'],
            'public_stats_viewable': status['publicStatsViewable'],
        }
    return None

# Example keyword (replace with your own keyword)
keyword = 'Electric Scooters'

# Search for videos by keyword and collect metadata
video_ids = search_videos_by_keyword(keyword)
data = []
for video_id in video_ids:
    metadata = get_video_metadata(video_id)
    if metadata:
        data.append(metadata)

# Display collected metadata
data
# Out:
# [{'video_id': 'YuG_AFUxgMY',
#   'title': 'TOP 10 BEST ELECTRIC SCOOTERS (2022 - 2023)',
#   'description': "What's the best electric scooter? Electric scooters are becoming more and more popular as a mode of transportation, and with good reason: they're cheap to operate, easy to maintain, and perfect for short commutes. Here are the 10 best electric scooters money can buy. From foldable to heavy-duty, we've got you covered. \n\nHere is the list:\n\n-Kaabo Wolf Warrior X \n-Apollo City Pro\n-EMOVE Cruiser\n-Dualtron Ultra 2 UP\xa0\n-Kaabo Wolf King GT Pro\n-Weped FF\n-Segway GT2\n-Inokim Light 2\xa0\n-Turboant V8\n-Hiboy S2 \n\n#electricscooter #scooter #trendmax \n\n---------------------------------------------------------------------------\nAbout Us:\n\nTrend Max is an education and entertainment channel dedicated to creating interesting Tops, Lists and more. Do not miss a single video SUBSCRIBE NOW.",
#   'tags': ['best electric scooters 2022',
#    'best electric scooter',
#    'electric scooter 2022',
#    'electric scooter',
#    'segway gt2',
#    'kaabo wolf warrior x',
#    'apollo city pro',
#    'emove cruiser',
#    'dualtron ultra 2 up',
#    'kaabo wolf king gt pro',
#    'weped ff',
#    'inokim light 2',
#    'turboant v8',
#    'hiboy s2',
#    'scooter',
#    'electric',
#    'top 10',
#    'trend max'],
#   'published_at': '2022-11-18T16:59:02Z',
#   'channel_id': 'UCta3MuD7omvsJyb-SMQkKOQ',
#   'channel_title': 'Trend Max',
#   'category_id': '28',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en-US',
#   'view_count': 702622,
#   'like_count': 5414,
#   'dislike_count': 0,
#   'comment_count': 326,
#   'duration': 'PT10M18S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'HSCyHyA-pQ8',
#   'title': 'Xiaomi Mi 1S Electric Scooter TOP SPEED (Environment Sound Only) 4K',
#   'description': '#topspeed DOWNHILL',
#   'tags': [],
#   'published_at': '2021-05-18T20:49:29Z',
#   'channel_id': 'UC-nMZSmRgMSNWXLinEDxekg',
#   'channel_title': 'ozandoganbey',
#   'category_id': '22',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'zxx',
#   'view_count': 1955740,
#   'like_count': 14637,
#   'dislike_count': 0,
#   'comment_count': 644,
#   'duration': 'PT52S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'JbpLjkhxHqs',
#   'title': 'Electric Scooter WEPED Sonic Burnout',
#   'description': 'WEPED Director Mr. Jeon\nWhatsApp : +821033333071\nwepedmall@naver.com\n\nWorldwide Free Shipping 🌎🌍🌏 ✈️\n\n👇🏻 You can purchase here.👇🏻\nhttps://www.weped-usa.com/product/weped-sonic-dual-e-scooter/251/category/24/display/1/\n\n-\nThis E-scooter is a WEPED Sonic\nBattery MAX Capacity : 8.4kWh / 72V 100a (Samsung SDI 21700 50E)\nMax Speed 140km/h ±10  (90MPH ±5)\n-\nShopping mall ➡️ http://www.weped-usa.com\nKR  ➡️ http://www.wepedmall.com\nInstagram ➡️ https://www.instagram.com/weped_official/\n\n#madeinKorea #weped #sonic #powerful #fast #sonic #electric scooter #WEPED Sonic #bmw Race #Exciting',
#   'tags': ['WEPED Sonic',
#    'WEPED',
#    'Tesla Cybertruck',
#    'Cyberfold',
#    'Electric Motorcycle',
#    'motorcycle',
#    'electric scooter',
#    'WEPED Dark Knight',
#    'Dark Knight',
#    'FOLD 2',
#    'WEPED Dark Knight 72V 90a',
#    '72V 90a',
#    '전동스쿠터',
#    '위페드',
#    '다크나이트',
#    'Day & Night Riding',
#    'Perfect Machine',
#    'USA',
#    '82 MPH',
#    'Seoul Tour',
#    '130km',
#    'WEPED Dark Knight Review',
#    'World Best',
#    'World Best Electric Scooter',
#    '소닉',
#    'sonic',
#    '위페드 소닉',
#    '2023 Electric Scooter',
#    'Performance driving',
#    'BMW M850i Drag Race',
#    'Exciting',
#    'late Night Run',
#    'Apgujeong-dong',
#    'Insane Faster',
#    'Burnout'],
#   'published_at': '2023-03-31T08:52:10Z',
#   'channel_id': 'UCFr4tLw88OQC1CZnjRb3Jwg',
#   'channel_title': 'WEPED 연제혁',
#   'category_id': '2',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en',
#   'view_count': 9970426,
#   'like_count': 173900,
#   'dislike_count': 0,
#   'comment_count': 1138,
#   'duration': 'PT8S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'DJ53WymRJLc',
#   'title': 'The CYBERTRUCK of Electric Scooters',
#   'description': '',
#   'tags': [],
#   'published_at': '2024-06-17T23:17:46Z',
#   'channel_id': 'UCkSVnUZq3q14lVajaQAlLpA',
#   'channel_title': 'Nathan Espinoza',
#   'category_id': '28',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en',
#   'view_count': 3589647,
#   'like_count': 170778,
#   'dislike_count': 0,
#   'comment_count': 903,
#   'duration': 'PT42S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'gPhmhVL-g1g',
#   'title': '#shorts | No Kick Scooter | E MOTORAD LIL E',
#   'description': "E MOTORAD LIL E NO KICK SCOOTER Detailed Review Video 👇\nhttps://youtu.be/ueXoKX8AOQg\n\nE MOTORAD\nLIL E NO KICK SCOOTER\nhttps://emotorad.com/bikes/lile\n\n👇👇👇👇👇👇👇👇👇👇👇\nPROMO CODE : GEARUPDATE\n\n😍😍 Use This CODE 👆 You'll Get Accessories worth Rs 3000 😍😍\n\nIMPORTANT NOTE* (code is valid till 15th April 2023)\n\n#shorts\n#shortsviral \n#shortsvideo\n#shortsyoutube\n#new\n#jamshedpur\n#emotorad \n#scooter",
#   'tags': ['New', 'Electric', 'E MOTORAD', 'No kick scooter'],
#   'published_at': '2022-10-16T17:08:53Z',
#   'channel_id': 'UCukVAyWJuBN-GSxn3ziOdkw',
#   'channel_title': 'GEAR UPDATE',
#   'category_id': '2',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'hi',
#   'view_count': 571680,
#   'like_count': 8971,
#   'dislike_count': 0,
#   'comment_count': 45,
#   'duration': 'PT15S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'L8ZlmMh2J-E',
#   'title': 'Folding the Segway-Ninebot E22 electric kick scooter is as easy as 1, 2, 3!',
#   'description': '',
#   'tags': [],
#   'published_at': '2022-08-30T14:59:39Z',
#   'channel_id': 'UCsTp7_ZWPP63DeMOS8fir6Q',
#   'channel_title': 'Scooterz Malaysia',
#   'category_id': '22',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'N/A',
#   'view_count': 377771,
#   'like_count': 5618,
#   'dislike_count': 0,
#   'comment_count': 47,
#   'duration': 'PT12S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': False,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'jazv7mRGnw0',
#   'title': '【SuperFun S10pro】How to Install the Seat On the Electric Scooter?',
#   'description': '【Folding Design】One-step folding system, with seat, easy storage in car trunks.\n【Perfect For Commute And Travel】Lightweight, perfect for a short commute or getting around town.\n\nLearn More about this Scooter：https://www.superfunebike.com/products/superfun-s10pro',
#   'tags': ['Electric Scooter',
#    'best electric scooter',
#    'good electric scooter',
#    'electric scooter 20 mph',
#    'foldable electric scooter',
#    'stand up electric scooter',
#    'small electric scooter',
#    'best cheap electric scooter for adults',
#    'best affordable electric scooter',
#    'electric scooter affordable',
#    'Superfun Electric Scooter',
#    'Electric Scooter Factory',
#    'Scooter Factory',
#    'Superfun S10pro',
#    'S10pro Foldable Electric Scooter',
#    'Superfun S10pro Electric Scooter',
#    'S10pro Electric Scooter',
#    'Superfun S10pro Scooter'],
#   'published_at': '2024-07-22T13:00:45Z',
#   'channel_id': 'UCcIrWrJmaIEFsCbzDJKm01Q',
#   'channel_title': 'SuperFun',
#   'category_id': '2',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'N/A',
#   'view_count': 520,
#   'like_count': 11,
#   'dislike_count': 0,
#   'comment_count': 0,
#   'duration': 'PT47S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': False,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'Mcqgwf_IaAw',
#   'title': 'Best Electric Scooters Of India - Who Promises The Most Range, Performance & Features?',
#   'description': 'The electric age for us two-wheeler enthusiasts is bitter sweet. While high performance e-bikes are few, our daily commutes are getting exciting as e-scooters lead the charge. Here are the best six e-scooter on sale in India today. Each brand and model is ensuring the basics like decent range and performance is met, but are offering something special to stand out from the crowd. On this world environmental day, we break down their specs of each one to help you know which one of these e-scooters is the one for you.   \n\nFor More Information: \n\nOLA S1: https://www.zigwheels.com/newbikes/Ola-Electric/Ola-S1\n\nBajaj Chetak: https://www.zigwheels.com/newbikes/Bajaj/chetak\n\nKey Moments:\n\n00:00 Introduction\n00:23 Performance and Topspeed\n1:01 Battery & Range\n3:32 Practicality and Livability\n4:50 Features\n5:46 Price\n6:30 Verdict\n7:15 Subscribe to ZigWheels\n\nMust Watch:\n\nOla S1 Pro vs Ather 450X vs TVS iQube vs Bajaj Chetak: https://www.youtube.com/watch?v=8wv_qiHjMDc&t=0s\n\nA Weekend Ride On Ola S1 Pro, Ather 450X, TVS iQube S And Bajaj Chetak: https://www.youtube.com/watch?v=3pusJa0Aj18&t=0s\n\nFollow us on Instagram: https://www.instagram.com/zigwheels/\nFollow us on Twitter: https://twitter.com/zigwheels/\nLike us on Facebook: https://www.facebook.com/zigwheels/\n\nDownload the ZigWheels App:\nAndroid: https://tinyurl.com/ZigWheelsApp\niOS: https://tinyurl.com/ZigWheelsAppIOS\n\n#olaelectricscooter #electric #scooter #2023',
#   'tags': ['ZigWheels',
#    'Zigwheels.com',
#    'Zigwheels review',
#    'best ev two wheeler india',
#    'best ev two wheeler in india 2023',
#    'top ev two wheelers in india',
#    'best two wheeler ev stocks in india',
#    'best ev two wheeler in india 2022',
#    'best range ev two wheeler in india',
#    'top ev two-wheeler companies in india',
#    'best electric vehicle two wheeler in india',
#    'best ev two wheeler in india',
#    'best ev two wheeler india and',
#    'world environment day india',
#    'world environment day india 2023',
#    'world environment day in india'],
#   'published_at': '2023-06-05T14:45:01Z',
#   'channel_id': 'UCjmjWp38PCg15Z5ZS-tmpfw',
#   'channel_title': 'ZigWheels',
#   'category_id': '2',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en',
#   'view_count': 77923,
#   'like_count': 608,
#   'dislike_count': 0,
#   'comment_count': 58,
#   'duration': 'PT7M33S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': '8sk3svkpwRw',
#   'title': '2022 Pure EV EPluto 7G Top Speed! Electric Scooter ⚡️',
#   'description': '',
#   'tags': [],
#   'published_at': '2022-04-28T15:37:54Z',
#   'channel_id': 'UCJ2ZPQOCIpw-WsQS6gv1Tqg',
#   'channel_title': 'AutoRevzz Hindi',
#   'category_id': '2',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'N/A',
#   'view_count': 1234930,
#   'like_count': 27604,
#   'dislike_count': 0,
#   'comment_count': 113,
#   'duration': 'PT22S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'SNLUr8lF0c4',
#   'title': 'Best Electric Scooter for Commuters',
#   'description': "This scooter has a lock, handle, passcode, and goes 20mph!\n\nFollow me on social media! (it's always just @mikeobrienn)\nInstagram: https://instagram.com/mikeobrienn\nTwitter: https://twitter.com/mikeobrienn\nTikTok: https://tiktok.com/@mikeobrienn\nAbout me: https://mikeobrienmedia.com\n\nPlease comment below with any questions you might have.  Thank you all for watching! I appreciate you!\n\n\nDisclaimer: This video is purely based on my experiences, research, and opinions.  You and only you are responsible for your actions.  I made this channel to advise viewers and I truly hope to help you all out.  I love making these videos and connecting with my viewers!\nOne or more of the products shown in this video may have been sent to me at no cost. This does not influence my opinions; I always cover both pros and cons.\nThis channel is monetized via YouTube ads as well as some affiliate links.  If a purchase is made after clicking the link, I will receive a small commission at no extra charge to the buyer.  Thank you all for watching!",
#   'tags': [],
#   'published_at': '2023-04-15T14:00:26Z',
#   'channel_id': 'UCZZ4ivUawsXRktLKej8d6Xw',
#   'channel_title': "Mike O'Brien",
#   'category_id': '28',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en',
#   'view_count': 375166,
#   'like_count': 10358,
#   'dislike_count': 0,
#   'comment_count': 134,
#   'duration': 'PT34S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'wDf3-F5Ic9I',
#   'title': 'Dual suspension system | Xiaomi Electric Scooter 4 Ultra',
#   'description': 'Get ready to glide into the future with the fully upgraded #XiaomiElectricScooter4Ultra 🛴\n\nSay goodbye to vibration and jolts and hello to a more comfortable, safer, and smarter ride. \n\n👉 http://s.mi.com/_NJ3QwM5\n\nLearn More:\nhttp://s.mi.com/BTl0HI52 (Official website)\nhttps://twitter.com/xiaomi  (Twitter)\nhttps://facebook.com/xiaomiglobal (Facebook)\nhttps://instagram.com/xiaomi.global (Instagram)\nhttps://www.tiktok.com/@xiaomi.official (TikTok)\nhttps://www.pinterest.com/xiaomiglobal (Pinterest)\nhttps://c.mi.com (Xiaomi community)\nhttps://blog.mi.com (Xiaomi Blog)',
#   'tags': ['Xiaomi',
#    'Redmi',
#    'Xiaomi MIUI',
#    'Xiaomi Phone',
#    'Xiaomi smartphone',
#    'Xiaomi product',
#    'Xiaomi smarthome',
#    'Mi',
#    'Mi Smarthome',
#    'Mi Home',
#    'MIUI',
#    'Xiaomi Studios',
#    'Mi Stery BOX',
#    'Shootlikeapro',
#    'redmi',
#    'Redmi Note',
#    'Xiaomi studios',
#    'Xiaomi 11',
#    'Smart Glasses',
#    'Smartphone',
#    'Device',
#    'Vacuum cleaner',
#    'youtube',
#    'smart',
#    'home',
#    'Mi 10',
#    'phone',
#    'smartphone',
#    'innovation',
#    'tech',
#    'charger',
#    'Xiaomi 12',
#    'mi 12'],
#   'published_at': '2023-03-06T15:00:45Z',
#   'channel_id': 'UCCspJ6mFfCwOV4qFjZWi2wg',
#   'channel_title': 'Xiaomi',
#   'category_id': '28',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en-GB',
#   'view_count': 663835,
#   'like_count': 8101,
#   'dislike_count': 0,
#   'comment_count': 415,
#   'duration': 'PT47S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': False,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': '47m1zakHrUY',
#   'title': 'Kaabo Wolf King Electric Scooter',
#   'description': '',
#   'tags': [],
#   'published_at': '2022-09-23T12:16:51Z',
#   'channel_id': 'UCalHx1uygc_uf24s_FRs7_A',
#   'channel_title': 'antssta',
#   'category_id': '17',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'N/A',
#   'view_count': 9347607,
#   'like_count': 0,
#   'dislike_count': 0,
#   'comment_count': 582,
#   'duration': 'PT9S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'Zq7ixPsttSE',
#   'title': '5 Best Fat Tire Electric Scooters 2023 | Best Fat Tire Scooter 2023',
#   'description': "5 Best Fat Tire Electric Scooters 2023\n\n00:00 - Introduction\n\n01:11 - 1. Eahora Etwister M2\n🛒: https://amzn.to/3VYFWlt\n\n03:26 - 2. Dynalion H4-Pro Citycoco\n🛒: https://amzn.to/3xi2jb7\n\n05:33 - 3. Eahora Emars M1P\n🛒: https://amzn.to/4cE8Vk3\n\n07:46 - 4. Phatty G3\n🛒: https://amzn.to/3J0GeR2\n\n10:18 - 5. Zoomer 1\n🛒: https://amzn.to/3IYqAp0\n\n**************************\n#commisionsearned \n**************************\nFat Tire or moped electric scooters are popular among riders who commute to work regularly. Fat tire electric scooters are a step up from the regular ones available. \nTo give you a comprehensive idea of how good Fat Tire's electric scooters are, we have explained everything that you need to know about them. This video will cover the top fat tire electric scooters in the market in 2022\n**************************\nDisclosure:- I maintain an independent association with the items showcased in this video, sans any sponsorships. The links provided below are affiliated, implying a minor commission is garnered from purchases made through them. This un-sponsored stance grants me the liberty to present unbiased reviews and suggestions. Amidst a myriad of choices, I diligently handpick products that have undergone my personal testing and earn my earnest approval. Your support is instrumental in delivering honest and valuable insights, which in turn, positively impacts my family's livelihood. I am grateful for your accompaniment in this endeavor.\n**************************\nCopyright Issue:- If you find any of your copyrighted material in this video, please leave us a message so we can resolve the issue within 24 hours.\n**************************\nThanks for watching this video!!! Please remember to leave a like and subscribe to our channel to see more videos like this in the future, and if you have any questions related to the products we listed here, leave a comment down below and I will get back to you as soon as I can!\n**************************\n#FatTireElectricScooter \n#FatTireScooters \n#ElectricMoped",
#   'tags': ['best fat tire electric scooters 2022',
#    'best fat tire electric scooter 2022',
#    'best fat tire electric scooters',
#    'best fat tire electric scooter',
#    'fat tire electric scooter 2022',
#    'fat tire electric scooter',
#    'fat tire electric scooters',
#    'best fat tire scooter 2022',
#    'electric scooter',
#    'best electric scooter',
#    'best electric scooter 2022',
#    'electric scooter 2022',
#    'best electric scooters 2022',
#    'electric scooter review',
#    'electric scooters',
#    'fastest electric scooter',
#    'citycoco electric scooter',
#    'scooter'],
#   'published_at': '2022-08-19T12:11:08Z',
#   'channel_id': 'UCPrfNyL7yN-15Q6Eu7UYkOA',
#   'channel_title': 'TechTrends',
#   'category_id': '28',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en-US',
#   'view_count': 130450,
#   'like_count': 1343,
#   'dislike_count': 0,
#   'comment_count': 60,
#   'duration': 'PT12M46S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'EHnErMI8Cgg',
#   'title': 'How to Ride an Electric Scooter: Complete Guide & Tips',
#   'description': 'A detailed tutorial on the basics of riding all types of electric scooters! Includes lots of riding tips.\n\nMy Favorite Scooters & Gear: https://storefront.throne.com/rk9rides\nCheck out my website for more reviews: https://www.rk9rides.com\nFollow me on Instagram, TikTok, and Facebook: https://linktr.ee/rk9rides\n\nTimestamps:\n0:00 Intro\n0:26 Before You Ride\n3:39 Take Off/Launch\n6:33 Accelerating & Braking\n8:01 Turning/Cornering\n\nLinks:\nScooter Featured (Varla Pegasus): https://bit.ly/3HF0w1V\nCode "RK9" at checkout for discount!\nScootering Basics Playlist: https://youtube.com/playlist?list=PL3vl6Vy8YF39YE-bwwfkVa2x6uxtubkLU\nCheck out my favorite electric scooters here: https://youtu.be/DxpYU3N_8R0\nCheck out my favorite electric scooter gear here: https://bit.ly/3nTtkcm',
#   'tags': ['how to',
#    'tutorial',
#    'electric scooter',
#    'how to ride electric scooter',
#    'electric scooter tutorial'],
#   'published_at': '2022-01-12T18:08:42Z',
#   'channel_id': 'UCFLRA2zhUOu1WIUH0gR3Z4A',
#   'channel_title': 'RK9 Rides',
#   'category_id': '2',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'N/A',
#   'view_count': 208524,
#   'like_count': 4723,
#   'dislike_count': 0,
#   'comment_count': 227,
#   'duration': 'PT12M47S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'dKmlaayz-tU',
#   'title': "I Bought the BUGATTI Electric Scooter So You Don't Have To",
#   'description': 'The new Bugatti electric scooter is not what I expected...\n\nIs this an authentic Bugatti escooter? Share your thoughts down below!\n\nCheck out the Bugatti Electric Scooter https://bugattiscootersna.com/\n\nMy Sur Ron:\n- Controller:  @E-Moto Bros   ASI BAC4000 https://emotobros.com/\n- Battery: 72v 38Ah from Chi Batteries ✅  5% off with code "SURRONSTER" ✅  https://chibatterysystems.com/?ref=SURRONSTER\n- Most parts listed here https://youtu.be/1b3jac9CcVw\n\nkey words: electric scooter escooter bugatti bugati review unboxing test first impression top speed wheelie new',
#   'tags': ['bugatti',
#    'bugati',
#    'electric',
#    'escooter',
#    'scooter',
#    'review',
#    'unboxing',
#    'surronster',
#    'bought',
#    'test',
#    'best',
#    'worst'],
#   'published_at': '2022-08-13T13:00:18Z',
#   'channel_id': 'UC_1QUZJSTYqda_dVYlNV03w',
#   'channel_title': 'Sur Ronster',
#   'category_id': '2',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en-US',
#   'view_count': 2898213,
#   'like_count': 34879,
#   'dislike_count': 0,
#   'comment_count': 1779,
#   'duration': 'PT7M23S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'u1SZJV_C8Aw',
#   'title': '5 CHEAP Electric Scooters! 🛴',
#   'description': 'Full review video: https://youtu.be/gkyZ9eq2dbQ\n#shorts',
#   'tags': [],
#   'published_at': '2022-12-28T21:00:30Z',
#   'channel_id': 'UCgyvzxg11MtNDfgDQKqlPvQ',
#   'channel_title': 'AuthenTech - Ben Schmanke',
#   'category_id': '28',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en',
#   'view_count': 279148,
#   'like_count': 6824,
#   'dislike_count': 0,
#   'comment_count': 38,
#   'duration': 'PT54S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'lsC8Fd7Hb1w',
#   'title': 'Top 5 Best Cheap Scooters 2023! - We Tested Them All!',
#   'description': 'Our Cheapest list yet! We tested every Cheap Electric Scooter we could find in 2021 and 2022 and even more New Scooters for 2023! \n\n🚨SEE Best Cheap Scooters ⬇️\nSegway E2 Plus: https://geni.us/SegwayE2Plus?track=ytec\n\nGotrax G3 Plus: https://geni.us/GotraxG3?track=ytec \n\nNIU KQi2 Pro: https://geni.us/NIUKQi2?track=ytec\n\nUnagi- https://geni.us/150-Off-Unagi\n1st Free Month Rent🏷️\n\nHiboy S2: https://geni.us/HiboyS2?track=ytec\n\nGotrax Flex: https://geni.us/GotraxFlex?track=ytec \n\nTurboant X7 Max: https://geni.us/X7Max?track=ytec\n\nEMOVE Touring: https://geni.us/Touring?track=ytec \n$50 OFF CODE-RIDERGUIDE🏷️\n\nApollo Air: https://geni.us/ApolloAir2023?track=ytec\n$50 OFF CODE-RIDERGUIDE🏷️\n\n🚨RECOMMENDED ACCESSORIES \n🔦Shredlights-https://geni.us/ShredLights\n🎟️Get 10% OFF with Code RG10\n🛞Armor-Dilloz Tire Sealant-https://geni.us/ArmorDilloz\n🎟️Get 10% OFF with Code RG10\n⛑️Best Helmet List-https://geni.us/BestHelmetList\n🏬ESG Amazon Store- https://geni.us/RGAmazon\n\nELECTRIC SCOOTER LINKS\n➡️ Best Scooter List : https://geni.us/BestScooterList\n➡️ Scooter Reviews: https://geni.us/ScooterReviews\n➡️ Buying Guide: https://geni.us/BuyingGuide\n➡️ Ride Finder: https://geni.us/RideFinder\n\n🚨Please subscribe to both of our Youtube Channels and Turn on Notifications for all up to date content.\n\nhttp://www.youtube.com/@RiderGuide\nhttp://www.youtube.com/@ESG-ElectricScooterGuide\n🌐Website-https://riderguide.com\n🌐Website-https://electricscooterguide.com\n📸 Instagram-https://geni.us/RiderGuideIG\n💬 FB Group-https://geni.us/ESGFacebookGroup\n\n👉🏻Are you Scooter Curious? Have Commitment Issues? Try subscribing monthly to Unagi. You get one of the most stylish dual motor escooters available with zero maintenance and a perpetual warranty. Get a FREE MONTH with this link below\nhttps://geni.us/UnagiRental\n\n#electricscooter #cheapscooters #budgetelectricscooter #affordableelectricscooter',
#   'tags': ['electric scooter',
#    'best cheap scooters',
#    'budget electric scooter',
#    'cheap electric scooters',
#    'best affordable electric scooter',
#    'cheap escooter',
#    'affordable electric scooter',
#    'best budget electric scooter',
#    '2023 electric scooters',
#    'Best cheap scooters of 2023',
#    'cheap e scooter review',
#    'electric scooters',
#    'electric scooter 2023',
#    'best electric scooter 2023',
#    'budget electric scooter 2023',
#    'electric scooter guide',
#    'Rider Guide',
#    'Escooter',
#    'e scooter',
#    'best electric scooter',
#    'e scooter 2023'],
#   'published_at': '2023-05-28T15:00:26Z',
#   'channel_id': 'UCxCZG3mLNMgkEpUPoWqyPkQ',
#   'channel_title': 'Electric Scooter Guide',
#   'category_id': '28',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en',
#   'view_count': 309276,
#   'like_count': 4462,
#   'dislike_count': 0,
#   'comment_count': 358,
#   'duration': 'PT11M42S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'MkrhXU1jgcU',
#   'title': '$200 Walmart eScooter PROS & CONS ⚡️🛴',
#   'description': '5 scooters under $700 review: https://youtu.be/gkyZ9eq2dbQ\n#shorts',
#   'tags': [],
#   'published_at': '2022-12-20T21:00:09Z',
#   'channel_id': 'UCgyvzxg11MtNDfgDQKqlPvQ',
#   'channel_title': 'AuthenTech - Ben Schmanke',
#   'category_id': '28',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en',
#   'view_count': 1635579,
#   'like_count': 49533,
#   'dislike_count': 0,
#   'comment_count': 241,
#   'duration': 'PT40S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'IKXcUVd0P9U',
#   'title': 'The 6 best value e-scooters in 2023',
#   'description': "Whether you're looking for a cheap electric scooter, or something high-end and high powered - value for money is still towards the top of everybody's priority list.\n\nI've pulled together a list of the top 6 electric scooters in the world right now when it comes to value for money. We're taking a look at scooters from Windgoo, E-Dash, Techtron, Jeep and Inokim.\n\nAll of these scooters are picked with safety in mind, and we've provided a good range of e-scooters for a broad range of people, from people who are small and light, to those who are tall and/or heavy.\n\nOur best value scooters of 2023 guide will point you in the right direction, and we'll get you the best prices on scooters in the UK with our discount codes.\n\n1) Scooter 1 - WINDGOO M20\n\nBuy this scooter: https://electroheads.com/products/windgoo-m20-electric-scooter\n\nDISCOUNT CODE: RICH10\n\n\n2) Scooter 2 - E-DASH LE-1\n\nBuy this scooter: https://electroheads.com/products/e-dash-limited-edition-1-electric-scooter\n\nDISCOUNT CODE: RICH10\n\n\n3) Scooter 3: Techtron Pro 3500\n\nBuy this scooter: https://electroheads.com/products/techtron-pro-3500-electric-scooter\n\n\n4) Scooter 4: Techtron Ultra 5000\n\nBuy this scooter: https://electroheads.com/products/techtron-ultra-5000-electric-scooter\n\n\n5) Scooter 5: Jeep Camou 2xe\n\nBuy this scooter: https://electroheads.com/products/jeep-2xe-camou-electric-scooter\n\n\n6) Scooter 6: Inokim Quick 4 Super\n\nBuy this scooter: https://electroheads.com/products/inokim-quick-4-super\n\n\n0:00 - Intro\n0:40 - Windgoo M20\n2:46 - E-Dash LE1\n5:14 - Techtron Pro 3500\n7:23 - Techtron Ultra 5000\n11:30 - Jeep Camou 2XE\n13:02 - INOKIM Quick 4\n15:02 - Outro\n\n#electricscooters #scooter #scooterreview \n---\nWe couldn't do this without your awesome support! If you love what we do, please consider becoming a channel member: \n\nhttps://www.youtube.com/channel/UCgrtRCRLtmBzle7rjJxDUsg/join\n\nFollow us on social to keep up with all things Electroheads:\n\nhttp://www.twitter.com/TheElectroheads\nhttp://www.instagram.com/Electroheads\n\nCheck out the Electroheads website:\nhttp://www.electroheads.com",
#   'tags': ['Electroheads',
#    'electric scooters',
#    'e-scooters',
#    'scooters',
#    'scooter',
#    'scooter review',
#    'escooter review'],
#   'published_at': '2022-12-24T12:00:08Z',
#   'channel_id': 'UCgrtRCRLtmBzle7rjJxDUsg',
#   'channel_title': 'Electroheads',
#   'category_id': '2',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'N/A',
#   'view_count': 127786,
#   'like_count': 1185,
#   'dislike_count': 0,
#   'comment_count': 216,
#   'duration': 'PT16M6S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'p6eSh8HWYtA',
#   'title': 'The honest Pros & Cons of owning an electric scooter in Canada 🇨🇦',
#   'description': '',
#   'tags': [],
#   'published_at': '2023-03-08T11:00:38Z',
#   'channel_id': 'UCMZwLNA-bibmfv4ucX_gQrQ',
#   'channel_title': 'T-Dot Wheels',
#   'category_id': '2',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'N/A',
#   'view_count': 384083,
#   'like_count': 10117,
#   'dislike_count': 0,
#   'comment_count': 302,
#   'duration': 'PT1M',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': False,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'EzkLY2Pg-vo',
#   'title': 'This “74.5 MPH” Electric Scooter Might KILL You - Nanrobot LS7+ Review',
#   'description': "https://bit.ly/nanrobot-ls7plus-discount - Click here then use code JUICED at checkout for $80 off your order and to support my reviews on this channel ⚡️🤙😜 \nThe Nanrobot LS7+ is a 72 volt electric scooter capable of hitting a top speed of about 60 MPH depending on rider weight. Nanrobot claims this scooter can achieve 74.5 MPH which has not been demonstrated in real world riding conditions, but perhaps could be achieved riding in a vacuum in space, or on steep downhill such as the walls of the Grand Canyon. Why would you wanna go that fast anyway? In this Nanrobot LS7 plus review I was able to hit nearly 60 MPH as a 200 LB rider, and I was able to break a few personal bests for 0-20 and 0-30 acceleration runs which is the real thrill of dual motor high power electric scooters.\nIf you're looking for an adrenaline rush the Nanrobot LS7+ will not disappoint.",
#   'tags': ['electric scooter', 'fastest electric scooter'],
#   'published_at': '2024-04-08T15:00:09Z',
#   'channel_id': 'UCokIkOoK0CthfJXPllQhhOw',
#   'channel_title': 'Juiced Joyrides',
#   'category_id': '22',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'N/A',
#   'view_count': 193563,
#   'like_count': 2639,
#   'dislike_count': 0,
#   'comment_count': 251,
#   'duration': 'PT25M11S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'bNbruhWoN7Q',
#   'title': '🔥New Technology | next generation 🔥| Scooter Bike',
#   'description': '#technology #innovation #shorts\n#gaming #gamer #hitech #techie #hi-tech #technical #bike #scooter #invention #automobile',
#   'tags': ['tech',
#    'technology',
#    'hitech',
#    'innovation',
#    'invention',
#    'nextgeneration',
#    'hifi',
#    'bike',
#    'scooter',
#    'creative',
#    'creativity',
#    'speed',
#    'gadget',
#    'gadgets',
#    'SDgyan',
#    'sidnidz',
#    'two-wheeler',
#    'vehicles',
#    'vehicle',
#    'technical',
#    'latest'],
#   'published_at': '2021-10-17T07:50:40Z',
#   'channel_id': 'UCh8-ERdIP9Rn6M3tWLWiJ2A',
#   'channel_title': 'iamSunilDubey',
#   'category_id': '2',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'hi',
#   'view_count': 47655072,
#   'like_count': 723381,
#   'dislike_count': 0,
#   'comment_count': 4866,
#   'duration': 'PT12S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'Kl1H9fGOYDI',
#   'title': 'Xiaomi Electric Scooter 4 Ultra performance test | Xiaomi Insider',
#   'description': 'Check out the mind-blowing performance test of #XiaomiElectricScooter4Ultra by #XiaomiInsider. Witness its cutting-edge features in action! 🛴\n\n👉 http://s.mi.com/Pe84_o26\n\n\nLearn More:\nhttp://s.mi.com/BTl0HI52 (Official website)\nhttps://twitter.com/xiaomi  (Twitter)\nhttps://facebook.com/xiaomiglobal (Facebook)\nhttps://instagram.com/xiaomi.global (Instagram)\nhttps://www.tiktok.com/@xiaomi.official (TikTok)\nhttps://www.pinterest.com/xiaomiglobal (Pinterest)\nhttps://c.mi.com (Xiaomi community)\nhttps://blog.mi.com (Xiaomi Blog)',
#   'tags': ['Xiaomi',
#    'Redmi',
#    'Xiaomi MIUI',
#    'Xiaomi Phone',
#    'Xiaomi smartphone',
#    'Xiaomi product',
#    'Xiaomi smarthome',
#    'Mi',
#    'Mi Smarthome',
#    'Mi Home',
#    'MIUI',
#    'Xiaomi Studios',
#    'Mi Stery BOX',
#    'Shootlikeapro',
#    'redmi',
#    'Redmi Note',
#    'Xiaomi studios',
#    'Xiaomi 11',
#    'Smart Glasses',
#    'Smartphone',
#    'Device',
#    'Vacuum cleaner',
#    'youtube',
#    'smart',
#    'home',
#    'Mi 10',
#    'phone',
#    'smartphone',
#    'innovation',
#    'tech',
#    'charger',
#    'Xiaomi 12',
#    'mi 12'],
#   'published_at': '2023-03-12T10:00:10Z',
#   'channel_id': 'UCCspJ6mFfCwOV4qFjZWi2wg',
#   'channel_title': 'Xiaomi',
#   'category_id': '28',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en-GB',
#   'view_count': 345116,
#   'like_count': 2385,
#   'dislike_count': 0,
#   'comment_count': 275,
#   'duration': 'PT4M7S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'true',
#   'licensed_content': False,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'JqyzwbpYYqc',
#   'title': 'Boosted Rev: The Tesla of Electric Scooters!',
#   'description': "Boosted made a scooter. It's impressive, expensive and fun!\nBoosted Rev: https://bit.ly/2JvjQkI\nXiaomi's $400 scooter: https://amzn.to/2XWRHef\n\nMKBHD Merch: http://shop.MKBHD.com\n\nVideo Gear I use: http://kit.com/MKBHD/video-gear#recom...\nTech I'm using right now: https://www.amazon.com/shop/MKBHD\n\nIntro Track: Connery by Alltta\nPlaylist of MKBHD Intro music: https://goo.gl/B3AWV5\n\n~\nhttp://twitter.com/MKBHD\nhttp://instagram.com/MKBHD\nhttp://facebook.com/MKBHD",
#   'tags': ['Boosted',
#    'Boosted rev',
#    'Boosted scooter',
#    'scooter',
#    'Xiaomi',
#    'Boosted scooter vs',
#    'Boosted rev vs',
#    'electric scooter',
#    'boosted board',
#    'MKBHD'],
#   'published_at': '2019-07-11T20:15:15Z',
#   'channel_id': 'UCBJycsmduvYEL83R_U4JriQ',
#   'channel_title': 'Marques Brownlee',
#   'category_id': '28',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'N/A',
#   'view_count': 3729376,
#   'like_count': 82611,
#   'dislike_count': 0,
#   'comment_count': 5538,
#   'duration': 'PT7M46S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': '4UJOj_wsMMo',
#   'title': 'TOP 10 FASTEST ELECTRIC SCOOTERS 2021- 2022 | Insane power and speed',
#   'description': "If you're looking for the fastest electric scooters on the market, then this video is for you. We've compiled a list of 10 of the fastest electric scooters currently available to buy today. We'll talk about what makes these models so fast and help you decide which one is best for your needs.\n\nHere is the list: \n\n-Weped FS\n\n-Rion RE90 Racing Edition\n\n-Weped SST\n\n-RION\xa0THRUST\n\n-Dualtron Storm Limited \n\n-Dualtron X 2  \n\n- Dualtron Thunder 2\n\n-NAMI Burn-E \n\n-ZERO 11X \n\n-Weped FOLD COUPE\n\n#scooter #electricscooter #fast #trendmax\n\n---------------------------------------------------------------------------\nAbout Us:\n\nTrend Max is an education and entertainment channel dedicated to creating interesting Tops, Lists and more. Do not miss a single video SUBSCRIBE NOW.",
#   'tags': ['fastest electric scooter 2022',
#    'fastest electric scooter 2021',
#    'fastest electric scooter',
#    'electric scooter',
#    'e scooter',
#    'scooter',
#    'weped fs',
#    'weped fs max speed',
#    'rion re90 racing edition',
#    'weped sst',
#    'rion thrust scooter',
#    'dualtron storm limited',
#    'dualtron x2',
#    'dualtron thunder 2',
#    'nami burn',
#    'nami burn e scooter',
#    'zero 11x scooter',
#    'weped fold coupe',
#    'speed',
#    'fast',
#    'top',
#    'trend max'],
#   'published_at': '2021-11-05T15:45:01Z',
#   'channel_id': 'UCta3MuD7omvsJyb-SMQkKOQ',
#   'channel_title': 'Trend Max',
#   'category_id': '2',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en-US',
#   'view_count': 1032707,
#   'like_count': 9565,
#   'dislike_count': 0,
#   'comment_count': 512,
#   'duration': 'PT11M42S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'e3L_Hj4tKGE',
#   'title': 'TOP 7 ELECTRIC SCOOTERS 2022 (Best eScooters Tested!)',
#   'description': "These are the very best scooters by category, including best for long range, urban riding, off roading, commuting, and even going 63mph!\nPRODUCT LINKS ⬇️\nKaabo Wolf King GT Pro 👉 https://mikeobrienmedia.com/WolfKingGT\n    $50 off Kaabo with code MIKE50632\nTurboant M10 👉 https://mikeobrienmedia.com/Turboant-M10\n    $30 off with code ASDM10\nEMOVE Cruiser 👉 https://mikeobrienmedia.com/EMOVE-Cruiser\n    $50 off EMOVE with code MIKE50632\nVarla Eagle One 👉 https://mikeobrienmedia.com/Varla\nHiboy S2 Max 👉 https://mikeobrienmedia.com/Hiboy-S2-Max\nSegway Ninebot Max 👉 https://mikeobrienmedia.com/Segway-Ninebot-Max\nXiaomi Scooter 4 Pro 👉 https://www.mi.com/us/product/xiaomi-electric-scooter-4-pro/\n\n\nFollow me on social media! (it's always just @mikeobrienn)\nInstagram: https://instagram.com/mikeobrienn\nTwitter: https://twitter.com/mikeobrienn\nTikTok: https://tiktok.com/@mikeobrienn\nAbout me: https://mikeobrienmedia.com\n\nTHE CATEGORIES:\nBest Overall\nBest For Commuters\nBest Under $500\nBest Under $2,000\nBest For Urban Riding\nBest For Beginners\nBest For Long Range\n\nTOP TECH DEALS (Updated Continuously): \n* Wearables: https://mikeobrienmedia.com/wearable-deals\n* Tablets: https://mikeobrienmedia.com/tablet-deals\n* Phones: https://mikeobrienmedia.com/phone-deals\n \nPlease comment below with any questions you might have.  Thank you all for watching! I appreciate you!\n\nADDITIONAL REVIEW NOTES:\nGoTrax GMAX Ultra\n    20mph, 45mi/charge, $850\n\nVarla Eagle One\n    40mph, 40 miles, $1699, dual motor, 330lb rider limit\n\nTurboant M10\n    20mph, 18 miles, $450\n\nXiaomi Scooter S2 Pro\n    15mph, 34 mi, $650ish\n\n Hiboy S2 Max\n    19mph, 40 miles $750 \n\n EMOVE Cruiser\n    IPX6, 33mph, 62 miles, optional seat, $1,499\n\nWolf King GT Pro\n    $3,395 was $3,795 but my link\n    63mph, 74 miles, Samsung/LG batteries, IPX5, dual hydraulic brakes, sine wave controller, well built\n\n\nComplaints:\nEagle one\nUnreliable battery level meter \nStiff steering. Bad for light turns \nCruise control was tough. I wish there was manual adjustment \nBad headlights \nHard to tell if you’re in turbo/eco or single/dual\nWobbly steering column\n\n\nGoTrax\nSuper solid and reliable \nGreat headlights \nReal world range could be better (but I always go full speed, so oh well)\nSpeedometer is incorrect\n\n\nCruiser\nLoud motor\nFunky steering\nNice collapsible handlebars\nLong range\n\nTIMESTAMPS:\n0:00\n0:50 Categories\n1:10 Best For Commuters\n2:10 Best Under $500\n3:10 Best Under $2000\n5:30 Special Announcement\n5:45 Best Overall\n7:45 Best Long Range\n10:00 Best For Beginners\n11:50 Best For Urban Riding\n\nDisclaimer: This video is purely based on my experiences, research, and opinions.  You and only you are responsible for your actions.  I made this channel to advise viewers and I truly hope to help you all out.  I love making these videos and connecting with my viewers!\nThis channel is monetized via YouTube ads as well as some affiliate links.  If a purchase is made after clicking the link, I will receive a small commission at no extra charge to the buyer.  Some of the products in this video were sent to me at no cost. Some products in this video were sent via a loan for this video. All opinions are my own. This did not affect my review in any way. I cover both positives and negatives for all products. No brands mentioned in this video had early access to watch this video prior to publishing. Thank you all for watching!",
#   'tags': [],
#   'published_at': '2022-09-16T13:04:09Z',
#   'channel_id': 'UCZZ4ivUawsXRktLKej8d6Xw',
#   'channel_title': "Mike O'Brien",
#   'category_id': '28',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en',
#   'view_count': 100934,
#   'like_count': 1494,
#   'dislike_count': 0,
#   'comment_count': 104,
#   'duration': 'PT13M38S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'Tulxhr269cc',
#   'title': "I Bought Amazon's FASTEST Electric Scooter",
#   'description': 'Electric Scooter: https://amzn.to/3nmfSMN\n\nFrick dude this thing is quick....and a little janky\n\nLIVE UPDATES ON\nINSTAGRAM:  https://www.instagram.com/the_inja/\nFACEBOOK: https://www.facebook.com/injamotorcycles',
#   'tags': ['the inja',
#    'inja',
#    'electric',
#    'scooter',
#    'escooter',
#    'e-scooter',
#    'amazon',
#    'cheapest',
#    'prime',
#    'fastest',
#    'fast',
#    'racing',
#    'bought',
#    'uberscoot',
#    'scoot'],
#   'published_at': '2020-12-17T15:00:28Z',
#   'channel_id': 'UCCVtCmI75NoFEN_Ie8MD6gA',
#   'channel_title': 'The Inja',
#   'category_id': '2',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en',
#   'view_count': 1268342,
#   'like_count': 13950,
#   'dislike_count': 0,
#   'comment_count': 1262,
#   'duration': 'PT10M49S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': False},
#  {'video_id': 'JcwT3aQRU1Y',
#   'title': 'Top 5: Best Electric Scooters (2024)',
#   'description': 'Here is the list of Best Electric Scooters we listed in this video.\n\n1. NIU Electric Scooter\nhttps://bit.ly/3SWTxGs\n\n2. Segway Ninebot\nhttps://bit.ly/3T3CGC6\n\n3. Gotrax G4\nhttps://bit.ly/3T2NkZH\n\n4. Inmotion S1\nhttps://bit.ly/48EOO25\n\n5. Swagtron SG-5 Swagger\nhttps://bit.ly/49X4iQ6\n\nUnleash the thrill of the ride with the Best Electric Scooters! NIU Electric Scooter leads the pack, blending style with eco-friendly commuting. Segway Ninebot promises a smooth journey with advanced features for a delightful ride. Gotrax G4 stands out for its power and reliability, ensuring a swift and efficient commute. Inmotion S1 adds a touch of sophistication with its sleek design and smart functionalities. For those seeking a perfect balance of style and substance, Swagtron SG-5 Swagger is the go-to choice. Elevate your commuting experience with these top electric scooters, each offering a unique blend of performance and style. \n\n#electricscooter #bestscooter #techpicked\n\nSubscribe our channel for future updates:  https://www.youtube.com/channel/UC2W7CSp_qyL-nBvY66UFNMw?sub_confirmation=1\n\nVideo link: https://youtu.be/JcwT3aQRU1Y\n\nYou may also like:\nhttps://youtu.be/h8mLyq9znEo\nhttps://youtu.be/nTqTra5dq_4\n\nWe are also on:\nTwitter: https://twitter.com/techpicked\nFacebook: https://www.facebook.com/techpicked\nBusiness Email: mailtotechpicked@gmail.com\n\n►Disclaimer◄\nSome of the footage used in this video is not original content produced by Tech Picked. Portions of stock footage of products was gathered from multiple sources including, manufactures, fellow creators and various other sources. If something belongs to you, and you want it to be removed, please do not hesitate to contact us.',
#   'tags': ['best electric scooters 2024',
#    'electric scooters',
#    'electric scooters 2024',
#    'best electric scooter 2024',
#    'best electric scooter',
#    'best electric scooter 2023',
#    'electric scooter 2024',
#    'best scooters 2024',
#    'electric scooter',
#    'best scooter',
#    'tech picked',
#    'electric scooter review'],
#   'published_at': '2024-03-08T00:15:01Z',
#   'channel_id': 'UC2W7CSp_qyL-nBvY66UFNMw',
#   'channel_title': 'Tech Picked',
#   'category_id': '22',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en',
#   'view_count': 1367,
#   'like_count': 15,
#   'dislike_count': 0,
#   'comment_count': 0,
#   'duration': 'PT8M4S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': '5PydA6BjaEQ',
#   'title': 'INSANE $10,000 Electric Scooter (80mph!)',
# ...
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'qF9GArsffJU',
#   'title': 'Top 10 BEST Dual Motor Electric Scooters of 2022',
#   'description': 'THESE are the BEST Dual Motor electric scooters of 2022. Tune in to see our top 10 choices, plus more! SEE ALL SCOOTERS 🛴 BELOW ⬇️⬇️\n\n⬇️⬇️ CHECK OUT AWARD-WINNING SCOOTERS ⬇️⬇️\n🛴 Dualtron Thunder I: https://geni.us/Dualtron-Thunder?track=ytec\n🛴 Dualtron Thunder II: https://geni.us/Thunder2?track=ytec\n🛴 Kaabo Wolf King GT: https://geni.us/WolfKingGT?track=ytec\n🛴 Unagi Model One E500: https://geni.us/UnagiSubscribe?track=ytec (🚨 link gives $60 off!!)\n🛴 Kaabo Wolf Warrior X: https://geni.us/Wolf-WarriorX?track=ytec\n🛴 Varla Pegasus: https://geni.us/Pegasus?track=ytec\n🛴 Apollo Ghost:https://geni.us/Apollo-Ghost?track=ytec\n🛴 Kaabo Mantis V2: https://geni.us/Skywalker10H?track=ytec\n🛴 Vsett 10+: https://geni.us/Vsett10Plus?track=ytec\n🛴 NAMI BURN-E 2: https://geni.us/BurnE2?track=ytec\n🛴 Segway GT2: https://geni.us/SegwayGT?track=ytec\n🛴 Apollo City Pro: https://geni.us/CityPro?track=ytec\n🛴 EMOVE RoadRunner: https://geni.us/RoadRunner?track=ytec\n\n🚨RECOMMENDED ACCESSORIES \n🔦Shredlights-https://geni.us/ShredLights\n🎟️Get 10% OFF with Code RG10\n🛞Armor-Dilloz Tire Sealant-https://geni.us/ArmorDilloz\n🎟️Get 10% OFF with Code RG10\n⛑️Best Helmet List-https://geni.us/BestHelmetList\n🏬ESG Amazon Store- https://geni.us/RGAmazon\n\nELECTRIC SCOOTER LINKS\n➡️ Best Scooter List : https://geni.us/BestScooterList\n➡️ Scooter Reviews: https://geni.us/ScooterReviews\n➡️ Buying Guide: https://geni.us/BuyingGuide\n➡️ Ride Finder: https://geni.us/RideFinder\n\n🚨Please subscribe to both of our Youtube Channels and Turn on Notifications for all up to date content.\n\nhttp://www.youtube.com/@RiderGuide\nhttp://www.youtube.com/@ESG-ElectricScooterGuide\n🌐Website-https://riderguide.com\n🌐Website-https://electricscooterguide.com\n📸 Instagram-https://geni.us/RiderGuideIG\n💬 FB Group-https://geni.us/ESGFacebookGroup\n\n👉🏻Are you Scooter Curious? Have Commitment Issues? Try subscribing monthly to Unagi. You get one of the most stylish dual motor escooters available with zero maintenance and a perpetual warranty. Get a FREE MONTH with this link below\nhttps://geni.us/UnagiRental\n\n#electricscooter #dualmotor #bestscooters',
#   'tags': ['dual motor electric scooter',
#    'electric scooters for heavy riders',
#    'electric scooter',
#    'dualtron thunder 2',
#    'wolf warrior x',
#    'wolf king gt',
#    'Dualtron thunder II',
#    'wolf king gt pro',
#    'Kaabo wolf king gt pro',
#    'fast scooters',
#    'fastest scooters',
#    'unagi model one',
#    'apollo ghost',
#    'apollo city pro',
#    'segway gt2',
#    'nami burn-e 2',
#    'vsett 10+',
#    'emove roadrunner',
#    'kaabo mantis v2',
#    'varla pegasus',
#    'dualtron thunder',
#    'best dual motor electric scooters',
#    'top 10 dual motor scooters',
#    'fastest electric scooter'],
#   'published_at': '2022-07-01T00:00:13Z',
#   'channel_id': 'UCxCZG3mLNMgkEpUPoWqyPkQ',
#   'channel_title': 'Electric Scooter Guide',
#   'category_id': '2',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en-US',
#   'view_count': 289994,
#   'like_count': 4243,
#   'dislike_count': 0,
#   'comment_count': 558,
#   'duration': 'PT16M36S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'TTXBrPC5E_c',
#   'title': 'Xiaomi Scooter 3 Review: The Best Electric Scooter Just Got Better!',
#   'description': "✔️ Xiaomi Electric Scooter 3: 👉 https://geni.us/MiScooter-3\n\n👇Expand the description for MORE information and links👇 \n\n===================================================\n\n#miscooter #miscooter3 #electricscooters\n\n🎥 More Electric Scooter reviews\nhttps://www.youtube.com/watch?v=FvrSUC_mtMc&list=PLczsTBo27jX4OStAqv6v--Yy6NG6y8rEh \n\nIt's finally here! The long anticipated Mi Scooter. Improvements are quite many, although seem to be just minor at the first sight. \nNew motor hub, new display, some improved parts and the same great riding comfort and range. But is this good enough?!\n\n===================================================\n\n➡️ Product links & Information ◕‿◕ :  \n\n✔️ Xiaomi Electric Scooter 3: 👉 https://geni.us/MiScooter-3\n✔️ Xiaomi Electric Scooter Pro / 1S: 👉  https://geni.us/Mi-Scooter\n\n================================\n\n🎵 Music used in this video: \naudiio.com\n================================\n٩(-̮̮̃•̃) ۶\n================================\n\n🕹 Tech gear that I use:\n\n📸 Great CAMERA for Youtube: https://geni.us/mycAm\n📸 a bigger CAMERA: https://geni.us/nHrgUik\n📱  the best SMARTPHONE?: https://geni.us/8zgx   \n🚁 DJI's awesome DRONE: https://geni.us/44pgOd  \n⌚ My Favorite SMARTWATCH: https://geni.us/5l7I\n📷 A cool ACTION CAMERA: https://geni.us/EAjPFi\n📷 The best 360° CAMERA: https://geni.us/One-X2\n🚴 My SCOOTER: https://geni.us/5AC67Y\n🎥 the GIMBAL: https://geni.us/DRjj \n\n================================\n\nThank YOU for visiting the Tech4All channel! \n\nPlease support me by using the affiliate links provided above. This implies NO additional cost to your purchase and I might receive a minor percentage out of it. It greatly helps me to produce better and more videos. Thank you!\n...or...\n► 🍺💲 Buy me a coffee: https://geni.us/TIPME\n(─‿‿─)\n\n✉ for business inquiries and review ideas: 👉 contact@tech4all.net",
#   'tags': ['mi scooter 3',
#    'mi scooter 3 review',
#    'xiaomi scooter 3',
#    'xiaomi scooter 3 review',
#    'electric scooter',
#    'best electric scooter',
#    'xiaomi',
#    'mi scooter 3 price',
#    'mi scooter 3 setup',
#    'mi scooter 3 range',
#    'xiaomi scooter',
#    'electric scooter review',
#    'xiaomi m365 pro',
#    'electric scooter 2021',
#    'xiaomi mi electric scooter 3',
#    'mi electric scooter 3 india',
#    'mi electric scooter 3 unboxing',
#    'xiaomi pro 3',
#    'xiaomi electric scooter max speed',
#    'xiaomi electric scooter 3 vs pro 2'],
#   'published_at': '2021-08-31T11:15:01Z',
#   'channel_id': 'UCZDeyDl9zh65Zm5Tp7df0eQ',
#   'channel_title': 'Tech4All',
#   'category_id': '28',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en',
#   'view_count': 183160,
#   'like_count': 2211,
#   'dislike_count': 0,
#   'comment_count': 350,
#   'duration': 'PT11M12S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'raooBXk8eGw',
#   'title': 'The Most Anticipated Electric Scooter of 2024 - RoadRunner RX7 Review',
#   'description': 'The RX7 is the best equipped electric scooter we’ve ever seen, but does it live up to the hype? We fully test it to find out: real-world range test, top speed, acceleration and more!\n\n🛴RoadRunner RX7🛴\n🔗https://geni.us/RoadRunnerRX7\n🎟️Get $50 OFF with Code RG50\n\n🚨RECOMMENDED ACCESSORIES \n🔦Shredlights-https://geni.us/ShredLights\n🎟️Get 10% OFF with Code RG10\n🛞Armor-Dilloz-https://geni.us/ArmorDilloz\n🎟️Get 10% OFF with Code RG10\n🧥Beyond Riders-https://geni.us/BRJacket\n🎟️Get $10 OFF with Code RG10\n⛑️Best Helmet List-https://geni.us/BestHelmetList\n\n🚨Please subscribe to both of our Youtube Channels and Turn on Notifications for all up to date content.\n\nhttp://www.youtube.com/@RiderGuide\nhttp://www.youtube.com/@ESG-ElectricScooterGuide\n🌐Website-https://riderguide.com\n🌐Website-https://electricscooterguide.com\n📸 Instagram-https://geni.us/RiderGuideIG\n💬 FB Group-https://geni.us/ESGFacebookGroup\n\n👉🏻Are you Scooter Curious? Have Commitment Issues? Try subscribing monthly to Unagi. You get one of the most stylish dual motor escooters available with zero maintenance and a perpetual warranty. Get a FREE MONTH with this link below\nhttps://geni.us/UnagiRental\n\n#electricscooter #escooter #bestelectricscooters #roadrunnerscooters  #electricscooterguide #RoadRunnerRX7 \u200b\u2060@RoadRunnerScooters  @RiderGuide  @ESG-ElectricScooterGuide @ArmorDilloz @ShredLights @beyondriders',
#   'tags': ['electric scooter',
#    'escooter',
#    'e-scooter',
#    'Roadrunner RX7',
#    'RX7 scooter',
#    'fastest electric scooter',
#    'PMT scooter tires',
#    'roadrunner electric scooter',
#    'best electric scooter 2024'],
#   'published_at': '2024-07-20T13:00:52Z',
#   'channel_id': 'UCxCZG3mLNMgkEpUPoWqyPkQ',
#   'channel_title': 'Electric Scooter Guide',
#   'category_id': '28',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en',
#   'view_count': 17651,
#   'like_count': 560,
#   'dislike_count': 0,
#   'comment_count': 197,
#   'duration': 'PT15M35S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'VzmMd7VrJDU',
#   'title': 'All Terrain Outstorm Maxx Scooter Review | Off Road Electric Scooter | Electric Scooters |',
#   'description': "The Maxx is next level fun, on road or off, doesn't matter this thing gets up and goes more than I thought possible for a scooter.  I hit some crazy roads and have everything you need to know before you hit the trail.\n\nElectric Revolution Website\nhttps://electricrevolutionreviews.com/\n\nPick this up here for 3% off with code MIKEHYDE357\nhttps://www.rideoutstorm.com/?ref=pvo4sJb6\n\nGEAR UP:\nHelmet with tail light: https://amzn.to/3mCJFzD\nKnee/elbow pads: https://amzn.to/2HuTOzX\nBike Light: https://amzn.to/37BWztz\nRiding Gloves: https://amzn.to/3nBH8Hj\nWrist Guards: https://amzn.to/3mAFRim\n\nCheck out my buddies tech channel\nhttps://www.youtube.com/channel/UCjdlnmz-uwW5yE0Pl9yP1dg\n\nJesus Christs New Testament Church has been restored\nhttps://www.youtube.com/channel/UCdNjexbIS_NKJC4ZRwKf9ag\n\n#scooter #outstorm #offroadscooter",
#   'tags': ['e scooter',
#    'e-scooter',
#    'electric scooter',
#    'electric scooter review',
#    'e scooter review',
#    'who makes the best electric scooter',
#    'top rated e scooter',
#    'luxury e scooter',
#    'commuter e scooter',
#    'scooter',
#    'off road scooter',
#    'off road electric scooter',
#    'best off road scooter',
#    'top selling off road electric scooter',
#    'best off road electric scooter',
#    'off road scooter review',
#    'all terrain scooter',
#    'outstorm',
#    'outstorm maxx scooter',
#    'commuter scooter',
#    'durable off road scooter',
#    'best all terrain scooter'],
#   'published_at': '2021-01-20T01:56:35Z',
#   'channel_id': 'UC-6YsZ1GcOMIehkb8eHioUQ',
#   'channel_title': 'Electric Revolution',
#   'category_id': '28',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'N/A',
#   'view_count': 299897,
#   'like_count': 3482,
#   'dislike_count': 0,
#   'comment_count': 384,
#   'duration': 'PT8M42S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'cTfyVWoqsn4',
#   'title': 'Supra China thundar electric scooter with full power dual motor 2024',
#   'description': '#trending1 #supra #electricscooters\n\n@Asimvloggs',
#   'tags': [],
#   'published_at': '2024-06-03T07:49:04Z',
#   'channel_id': 'UCOE_BYsSE8adz0tTa7clL4w',
#   'channel_title': 'UAE scooters 🛴',
#   'category_id': '22',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'N/A',
#   'view_count': 33491,
#   'like_count': 372,
#   'dislike_count': 0,
#   'comment_count': 40,
#   'duration': 'PT1M12S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': False,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'xnwA7JoEmhc',
#   'title': '30000Rs Worth E Scooter 🛵#offsquad #shorts #youtubeshort',
#   'description': '#spoutoffocus\n#outoffocus \n#shorts \n#youtubeshort \nFull video link\nhttps://youtu.be/Nh_at-UTCnU',
#   'tags': ['Sp', 'OutofFocus', 'out of focus'],
#   'published_at': '2022-10-22T12:00:42Z',
#   'channel_id': 'UCROfQqnRGFqZiuwLywKEy9A',
#   'channel_title': 'Out of Focus',
#   'category_id': '26',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'ta',
#   'view_count': 18351587,
#   'like_count': 806344,
#   'dislike_count': 0,
#   'comment_count': 981,
#   'duration': 'PT36S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'E_a90DOqKTo',
#   'title': 'Electric Scooters in the UK. Almost a Ninebot….',
#   'description': '',
#   'tags': [],
#   'published_at': '2021-10-18T06:50:49Z',
#   'channel_id': 'UCLLA57zvDCDjv1lFy4BgJyQ',
#   'channel_title': 'Geordie Vape Man',
#   'category_id': '22',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'N/A',
#   'view_count': 53205,
#   'like_count': 1725,
#   'dislike_count': 0,
#   'comment_count': 22,
#   'duration': 'PT29S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': False,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True},
#  {'video_id': 'RYtn-3OVxeU',
#   'title': 'Best FAT TIRE Electric Scooters In 2023',
#   'description': "Fat tire electric scooters are all the rage right now. In this video, we review the best of them.\n\nHere's where you can find them:\n\nSay Yeah 800W: https://amzn.to/3jt7r27\nCitycoco: https://amzn.to/3nnpJmT\nMototec Fatboy: https://escooternerds.com/recommends/mototec-fat-boy-500w-walmart/\nToxozers Fatboy: https://amzn.to/3VQ2YHH\nMototec Vulcan: https://amzn.to/3VMKTKH\nZoomers: https://amzn.to/3iDguQv\nSay Yeah 2000W: https://amzn.to/3ipqYCX\n\nCheck the written version of this guide for a few other scooters with fat tires:\nhttps://escooternerds.com/fat-tire-electric-scooters/?utm_source=ytov\n\nTimestamps:\n0:00 - Intro\n0:31 - Say Yeah 800W\n1:38 - Citycoco\n2:55 - Scrooser\n4:56 - Stator\n6:58 - Skooza K1S\n7:53 - Mototec Fatboy\n8:57 - Toxozers Fatboy\n10:07 - Mototec Vulcan\n11:49 - Zoomers\n12:45 - Best fat tire electric scooter\n14:37 - Discounts, Coupons, Resources\n\nThe video uses footage from the following channels:\n\nhttps://www.youtube.com/@puppytech291/\nhttps://www.youtube.com/@VehiculosconIngenio\nhttps://www.youtube.com/@skooza\n\nThe video uses music from the following artists:\nFun Life by FASSounds\nRescue by prazkhanal\nDarkBeat76BPM by deleted user 984625 \nFairfax by Cxdy\nAnime by Lesfm\n\nThis channel is a participant in the Amazon Services LLC Associates Program, an affiliate advertising program designed to provide a means for sites to earn advertising fees by advertising and linking to amazon.com",
#   'tags': ['escooternerds',
#    'electric scooter',
#    'fat tire',
#    'fat tire scooter',
#    'fat tire electric scooter'],
#   'published_at': '2023-01-10T16:35:56Z',
#   'channel_id': 'UC3KXf9gnAOiC2kpiMnPbafA',
#   'channel_title': 'EScooterNerds',
#   'category_id': '2',
#   'live_broadcast_content': 'none',
#   'default_audio_language': 'en',
#   'view_count': 60833,
#   'like_count': 813,
#   'dislike_count': 0,
#   'comment_count': 50,
#   'duration': 'PT15M5S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensed_content': True,
#   'projection': 'rectangular',
#   'upload_status': 'processed',
#   'privacy_status': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'public_stats_viewable': True}]

# %%
# Create DataFrame
df = pd.DataFrame(data)

# Save to CSV
csv_buffer = StringIO()
df.to_csv('youtube_metadata.csv')
df.to_csv(csv_buffer, index=False)
df
# Out:
#        video_id                                              title  \
# 0   YuG_AFUxgMY        TOP 10 BEST ELECTRIC SCOOTERS (2022 - 2023)
# 1   HSCyHyA-pQ8  Xiaomi Mi 1S Electric Scooter TOP SPEED (Envir...
# 2   JbpLjkhxHqs               Electric Scooter WEPED Sonic Burnout
# 3   DJ53WymRJLc                The CYBERTRUCK of Electric Scooters
# 4   gPhmhVL-g1g        #shorts | No Kick Scooter | E MOTORAD LIL E
# 5   L8ZlmMh2J-E  Folding the Segway-Ninebot E22 electric kick s...
# 6   jazv7mRGnw0  【SuperFun S10pro】How to Install the Seat On th...
# 7   Mcqgwf_IaAw  Best Electric Scooters Of India - Who Promises...
# 8   8sk3svkpwRw  2022 Pure EV EPluto 7G Top Speed! Electric Sco...
# 9   SNLUr8lF0c4                Best Electric Scooter for Commuters
# 10  wDf3-F5Ic9I  Dual suspension system | Xiaomi Electric Scoot...
# 11  47m1zakHrUY                   Kaabo Wolf King Electric Scooter
# 12  Zq7ixPsttSE  5 Best Fat Tire Electric Scooters 2023 | Best ...
# 13  EHnErMI8Cgg  How to Ride an Electric Scooter: Complete Guid...
# 14  dKmlaayz-tU  I Bought the BUGATTI Electric Scooter So You D...
# 15  u1SZJV_C8Aw                       5 CHEAP Electric Scooters! 🛴
# 16  lsC8Fd7Hb1w  Top 5 Best Cheap Scooters 2023! - We Tested Th...
# 17  MkrhXU1jgcU              $200 Walmart eScooter PROS & CONS ⚡️🛴
# 18  IKXcUVd0P9U                The 6 best value e-scooters in 2023
# 19  p6eSh8HWYtA  The honest Pros & Cons of owning an electric s...
# 20  EzkLY2Pg-vo  This “74.5 MPH” Electric Scooter Might KILL Yo...
# 21  bNbruhWoN7Q  🔥New Technology | next generation 🔥| Scooter Bike
# 22  Kl1H9fGOYDI  Xiaomi Electric Scooter 4 Ultra performance te...
# 23  JqyzwbpYYqc       Boosted Rev: The Tesla of Electric Scooters!
# 24  4UJOj_wsMMo  TOP 10 FASTEST ELECTRIC SCOOTERS 2021- 2022 | ...
# 25  e3L_Hj4tKGE  TOP 7 ELECTRIC SCOOTERS 2022 (Best eScooters T...
# 26  Tulxhr269cc         I Bought Amazon's FASTEST Electric Scooter
# 27  JcwT3aQRU1Y               Top 5: Best Electric Scooters (2024)
# 28  5PydA6BjaEQ           INSANE $10,000 Electric Scooter (80mph!)
# 29  dGJtM6b7ULA            AOVO PRO Electric Scooter M365 Pro 2023
# 30  FdhPaB24oUU  Hiboy S2 ▏Electric scooters for efficient comm...
# 31  UPe7SZYnwT0  How To Ride An Electric Scooter | A Beginner's...
# 32  NXFn0pdXbQY  Top 10 Best Long Range Electric Scooters! - We...
# 33  _Ge76RP1Akk  Xiaomi 1S  Electric Scooter- Long Range City R...
# 34  E66wP7w5QyI              Top 10 Electric Scooters for Big Guys
# 35  cuYua90fpaI  The 12 Best Electric Scooters for Commuting - ...
# 36  K3LhTPgpstc  Top 5 New Electric Scooters of 2024 | Electric...
# 37  qF9GArsffJU   Top 10 BEST Dual Motor Electric Scooters of 2022
# 38  TTXBrPC5E_c  Xiaomi Scooter 3 Review: The Best Electric Sco...
# 39  raooBXk8eGw  The Most Anticipated Electric Scooter of 2024 ...
# 40  VzmMd7VrJDU  All Terrain Outstorm Maxx Scooter Review | Off...
# 41  cTfyVWoqsn4  Supra China thundar electric scooter with full...
# 42  xnwA7JoEmhc  30000Rs Worth E Scooter 🛵#offsquad #shorts #yo...
# 43  E_a90DOqKTo    Electric Scooters in the UK. Almost a Ninebot….
# 44  RYtn-3OVxeU            Best FAT TIRE Electric Scooters In 2023
#
#                                           description  \
# 0   What's the best electric scooter? Electric sco...
# 1                                  #topspeed DOWNHILL
# 2   WEPED Director Mr. Jeon\nWhatsApp : +821033333...
# 3
# 4   E MOTORAD LIL E NO KICK SCOOTER Detailed Revie...
# 5
# 6   【Folding Design】One-step folding system, with ...
# 7   The electric age for us two-wheeler enthusiast...
# 8
# 9   This scooter has a lock, handle, passcode, and...
# 10  Get ready to glide into the future with the fu...
# 11
# 12  5 Best Fat Tire Electric Scooters 2023\n\n00:0...
# 13  A detailed tutorial on the basics of riding al...
# 14  The new Bugatti electric scooter is not what I...
# 15  Full review video: https://youtu.be/gkyZ9eq2db...
# 16  Our Cheapest list yet! We tested every Cheap E...
# 17  5 scooters under $700 review: https://youtu.be...
# 18  Whether you're looking for a cheap electric sc...
# 19
# 20  https://bit.ly/nanrobot-ls7plus-discount - Cli...
# 21  #technology #innovation #shorts\n#gaming #game...
# 22  Check out the mind-blowing performance test of...
# 23  Boosted made a scooter. It's impressive, expen...
# 24  If you're looking for the fastest electric sco...
# 25  These are the very best scooters by category, ...
# 26  Electric Scooter: https://amzn.to/3nmfSMN\n\nF...
# 27  Here is the list of Best Electric Scooters we ...
# 28  Testing one of the fastest electric scooters i...
# 29  This video is showing off AOVO's M365 PRO Elec...
# 30  Foldable and portable for adult daily use. Fas...
# 31  An explanation of the basics of riding an e-sc...
# 32  We Conducted the World's Biggest Electric Scoo...
# 33  Xiaomi 1S Electric Scooter Long Range Ride in ...
# 34  Here are the best top 10 electric scooters for...
# 35  Ready to commute back to school or to the offi...
# 36  we'll be diving into the world of innovation a...
# 37  THESE are the BEST Dual Motor electric scooter...
# 38  ✔️ Xiaomi Electric Scooter 3: 👉 https://geni.u...
# 39  The RX7 is the best equipped electric scooter ...
# 40  The Maxx is next level fun, on road or off, do...
# 41  #trending1 #supra #electricscooters\n\n@Asimvl...
# 42  #spoutoffocus\n#outoffocus \n#shorts \n#youtub...
# 43
# 44  Fat tire electric scooters are all the rage ri...
#
#                                                  tags          published_at  \
# 0   [best electric scooters 2022, best electric sc...  2022-11-18T16:59:02Z
# 1                                                  []  2021-05-18T20:49:29Z
# 2   [WEPED Sonic, WEPED, Tesla Cybertruck, Cyberfo...  2023-03-31T08:52:10Z
# 3                                                  []  2024-06-17T23:17:46Z
# 4         [New, Electric, E MOTORAD, No kick scooter]  2022-10-16T17:08:53Z
# 5                                                  []  2022-08-30T14:59:39Z
# 6   [Electric Scooter, best electric scooter, good...  2024-07-22T13:00:45Z
# 7   [ZigWheels, Zigwheels.com, Zigwheels review, b...  2023-06-05T14:45:01Z
# 8                                                  []  2022-04-28T15:37:54Z
# 9                                                  []  2023-04-15T14:00:26Z
# 10  [Xiaomi, Redmi, Xiaomi MIUI, Xiaomi Phone, Xia...  2023-03-06T15:00:45Z
# 11                                                 []  2022-09-23T12:16:51Z
# 12  [best fat tire electric scooters 2022, best fa...  2022-08-19T12:11:08Z
# 13  [how to, tutorial, electric scooter, how to ri...  2022-01-12T18:08:42Z
# 14  [bugatti, bugati, electric, escooter, scooter,...  2022-08-13T13:00:18Z
# 15                                                 []  2022-12-28T21:00:30Z
# 16  [electric scooter, best cheap scooters, budget...  2023-05-28T15:00:26Z
# 17                                                 []  2022-12-20T21:00:09Z
# 18  [Electroheads, electric scooters, e-scooters, ...  2022-12-24T12:00:08Z
# 19                                                 []  2023-03-08T11:00:38Z
# 20       [electric scooter, fastest electric scooter]  2024-04-08T15:00:09Z
# 21  [tech, technology, hitech, innovation, inventi...  2021-10-17T07:50:40Z
# 22  [Xiaomi, Redmi, Xiaomi MIUI, Xiaomi Phone, Xia...  2023-03-12T10:00:10Z
# 23  [Boosted, Boosted rev, Boosted scooter, scoote...  2019-07-11T20:15:15Z
# 24  [fastest electric scooter 2022, fastest electr...  2021-11-05T15:45:01Z
# 25                                                 []  2022-09-16T13:04:09Z
# 26  [the inja, inja, electric, scooter, escooter, ...  2020-12-17T15:00:28Z
# 27  [best electric scooters 2024, electric scooter...  2024-03-08T00:15:01Z
# 28  [electric, scooter, escooter, fastest, expensi...  2024-02-24T16:00:07Z
# 29  [electric scooter, aovo electric scooter, chea...  2022-01-29T21:45:30Z
# 30                                                 []  2023-02-23T02:58:01Z
# 31                                                 []  2020-02-01T19:11:24Z
# 32  [top electric scooters for range, best long ra...  2022-03-01T01:18:08Z
# 33  [xiaomi mi electric scooter, xiaomi 1s, electr...  2021-07-29T23:47:38Z
# 34  [Uscooter GT Sport Electric Scooter Review, Wo...  2022-10-22T16:30:09Z
# 35  [best electric scooter, electric scooter, elec...  2022-10-08T16:00:19Z
# 36  [FutureTech, best electric scooter, new electr...  2023-09-21T00:00:07Z
# 37  [dual motor electric scooter, electric scooter...  2022-07-01T00:00:13Z
# 38  [mi scooter 3, mi scooter 3 review, xiaomi sco...  2021-08-31T11:15:01Z
# 39  [electric scooter, escooter, e-scooter, Roadru...  2024-07-20T13:00:52Z
# 40  [e scooter, e-scooter, electric scooter, elect...  2021-01-20T01:56:35Z
# 41                                                 []  2024-06-03T07:49:04Z
# 42                     [Sp, OutofFocus, out of focus]  2022-10-22T12:00:42Z
# 43                                                 []  2021-10-18T06:50:49Z
# 44  [escooternerds, electric scooter, fat tire, fa...  2023-01-10T16:35:56Z
#
#                   channel_id              channel_title category_id  \
# 0   UCta3MuD7omvsJyb-SMQkKOQ                  Trend Max          28
# 1   UC-nMZSmRgMSNWXLinEDxekg               ozandoganbey          22
# 2   UCFr4tLw88OQC1CZnjRb3Jwg                  WEPED 연제혁           2
# 3   UCkSVnUZq3q14lVajaQAlLpA            Nathan Espinoza          28
# 4   UCukVAyWJuBN-GSxn3ziOdkw                GEAR UPDATE           2
# 5   UCsTp7_ZWPP63DeMOS8fir6Q          Scooterz Malaysia          22
# 6   UCcIrWrJmaIEFsCbzDJKm01Q                   SuperFun           2
# 7   UCjmjWp38PCg15Z5ZS-tmpfw                  ZigWheels           2
# 8   UCJ2ZPQOCIpw-WsQS6gv1Tqg            AutoRevzz Hindi           2
# 9   UCZZ4ivUawsXRktLKej8d6Xw               Mike O'Brien          28
# 10  UCCspJ6mFfCwOV4qFjZWi2wg                     Xiaomi          28
# 11  UCalHx1uygc_uf24s_FRs7_A                    antssta          17
# 12  UCPrfNyL7yN-15Q6Eu7UYkOA                 TechTrends          28
# 13  UCFLRA2zhUOu1WIUH0gR3Z4A                  RK9 Rides           2
# 14  UC_1QUZJSTYqda_dVYlNV03w                Sur Ronster           2
# 15  UCgyvzxg11MtNDfgDQKqlPvQ  AuthenTech - Ben Schmanke          28
# 16  UCxCZG3mLNMgkEpUPoWqyPkQ     Electric Scooter Guide          28
# 17  UCgyvzxg11MtNDfgDQKqlPvQ  AuthenTech - Ben Schmanke          28
# 18  UCgrtRCRLtmBzle7rjJxDUsg               Electroheads           2
# 19  UCMZwLNA-bibmfv4ucX_gQrQ               T-Dot Wheels           2
# 20  UCokIkOoK0CthfJXPllQhhOw            Juiced Joyrides          22
# 21  UCh8-ERdIP9Rn6M3tWLWiJ2A              iamSunilDubey           2
# 22  UCCspJ6mFfCwOV4qFjZWi2wg                     Xiaomi          28
# 23  UCBJycsmduvYEL83R_U4JriQ           Marques Brownlee          28
# 24  UCta3MuD7omvsJyb-SMQkKOQ                  Trend Max           2
# 25  UCZZ4ivUawsXRktLKej8d6Xw               Mike O'Brien          28
# 26  UCCVtCmI75NoFEN_Ie8MD6gA                   The Inja           2
# 27  UC2W7CSp_qyL-nBvY66UFNMw                Tech Picked          22
# 28  UC_1QUZJSTYqda_dVYlNV03w                Sur Ronster           2
# 29  UCpgONso52_U8l8d5KM0UPKQ               Jake Billing          24
# 30  UCWgpT7y4778nNb-XLh0A1Cw             Hiboy official          17
# 31  UCShpPENn2qO1O5F6kpb4yqw                  Scootered          17
# 32  UCxCZG3mLNMgkEpUPoWqyPkQ     Electric Scooter Guide           2
# 33  UCvxLoZIegbfweTLrWBRW9mw            Just a Traveler          19
# 34  UCF9x1eG13h1iLm0IpUpTCHg             Tim's Electric          26
# 35  UCxCZG3mLNMgkEpUPoWqyPkQ     Electric Scooter Guide           2
# 36  UCz_Myes574ihap2wmMDd45Q                 FutureTech          28
# 37  UCxCZG3mLNMgkEpUPoWqyPkQ     Electric Scooter Guide           2
# 38  UCZDeyDl9zh65Zm5Tp7df0eQ                   Tech4All          28
# 39  UCxCZG3mLNMgkEpUPoWqyPkQ     Electric Scooter Guide          28
# 40  UC-6YsZ1GcOMIehkb8eHioUQ        Electric Revolution          28
# 41  UCOE_BYsSE8adz0tTa7clL4w             UAE scooters 🛴          22
# 42  UCROfQqnRGFqZiuwLywKEy9A               Out of Focus          26
# 43  UCLLA57zvDCDjv1lFy4BgJyQ           Geordie Vape Man          22
# 44  UC3KXf9gnAOiC2kpiMnPbafA              EScooterNerds           2
#
#    live_broadcast_content default_audio_language  ...  dimension  definition  \
# 0                    none                  en-US  ...         2d          hd
# 1                    none                    zxx  ...         2d          hd
# 2                    none                     en  ...         2d          hd
# 3                    none                     en  ...         2d          hd
# 4                    none                     hi  ...         2d          hd
# 5                    none                    N/A  ...         2d          hd
# 6                    none                    N/A  ...         2d          hd
# 7                    none                     en  ...         2d          hd
# 8                    none                    N/A  ...         2d          hd
# 9                    none                     en  ...         2d          hd
# 10                   none                  en-GB  ...         2d          hd
# 11                   none                    N/A  ...         2d          hd
# 12                   none                  en-US  ...         2d          hd
# 13                   none                    N/A  ...         2d          hd
# 14                   none                  en-US  ...         2d          hd
# 15                   none                     en  ...         2d          hd
# 16                   none                     en  ...         2d          hd
# 17                   none                     en  ...         2d          hd
# 18                   none                    N/A  ...         2d          hd
# 19                   none                    N/A  ...         2d          hd
# 20                   none                    N/A  ...         2d          hd
# 21                   none                     hi  ...         2d          hd
# 22                   none                  en-GB  ...         2d          hd
# 23                   none                    N/A  ...         2d          hd
# 24                   none                  en-US  ...         2d          hd
# 25                   none                     en  ...         2d          hd
# 26                   none                     en  ...         2d          hd
# 27                   none                     en  ...         2d          hd
# 28                   none                  en-US  ...         2d          hd
# 29                   none                  en-GB  ...         2d          hd
# 30                   none                  en-US  ...         2d          hd
# 31                   none                    N/A  ...         2d          hd
# 32                   none                  en-US  ...         2d          hd
# 33                   none                    N/A  ...         2d          hd
# 34                   none                     en  ...         2d          hd
# 35                   none                  en-US  ...         2d          hd
# 36                   none                  en-US  ...         2d          hd
# 37                   none                  en-US  ...         2d          hd
# 38                   none                     en  ...         2d          hd
# 39                   none                     en  ...         2d          hd
# 40                   none                    N/A  ...         2d          hd
# 41                   none                    N/A  ...         2d          hd
# 42                   none                     ta  ...         2d          hd
# 43                   none                    N/A  ...         2d          hd
# 44                   none                     en  ...         2d          hd
#
#     caption  licensed_content   projection upload_status privacy_status  \
# 0     false              True  rectangular     processed         public
# 1     false              True  rectangular     processed         public
# 2     false              True  rectangular     processed         public
# 3     false              True  rectangular     processed         public
# 4     false              True  rectangular     processed         public
# 5     false             False  rectangular     processed         public
# 6     false             False  rectangular     processed         public
# 7     false              True  rectangular     processed         public
# 8     false              True  rectangular     processed         public
# 9     false              True  rectangular     processed         public
# 10    false             False  rectangular     processed         public
# 11    false              True  rectangular     processed         public
# 12    false              True  rectangular     processed         public
# 13    false              True  rectangular     processed         public
# 14    false              True  rectangular     processed         public
# 15    false              True  rectangular     processed         public
# 16    false              True  rectangular     processed         public
# 17    false              True  rectangular     processed         public
# 18    false              True  rectangular     processed         public
# 19    false             False  rectangular     processed         public
# 20    false              True  rectangular     processed         public
# 21    false              True  rectangular     processed         public
# 22     true             False  rectangular     processed         public
# 23    false              True  rectangular     processed         public
# 24    false              True  rectangular     processed         public
# 25    false              True  rectangular     processed         public
# 26    false              True  rectangular     processed         public
# 27    false              True  rectangular     processed         public
# 28    false              True  rectangular     processed         public
# 29    false              True  rectangular     processed         public
# 30    false             False  rectangular     processed         public
# 31    false             False  rectangular     processed         public
# 32     true              True  rectangular     processed         public
# 33    false              True  rectangular     processed         public
# 34    false              True  rectangular     processed         public
# 35    false              True  rectangular     processed         public
# 36    false              True  rectangular     processed         public
# 37    false              True  rectangular     processed         public
# 38    false              True  rectangular     processed         public
# 39    false              True  rectangular     processed         public
# 40    false              True  rectangular     processed         public
# 41    false             False  rectangular     processed         public
# 42    false              True  rectangular     processed         public
# 43    false             False  rectangular     processed         public
# 44    false              True  rectangular     processed         public
#
#     license  embeddable public_stats_viewable
# 0   youtube        True                  True
# 1   youtube        True                  True
# 2   youtube        True                  True
# 3   youtube        True                  True
# 4   youtube        True                  True
# 5   youtube        True                  True
# 6   youtube        True                  True
# 7   youtube        True                  True
# 8   youtube        True                  True
# 9   youtube        True                  True
# 10  youtube        True                  True
# 11  youtube        True                  True
# 12  youtube        True                  True
# 13  youtube        True                  True
# 14  youtube        True                  True
# 15  youtube        True                  True
# 16  youtube        True                  True
# 17  youtube        True                  True
# 18  youtube        True                  True
# 19  youtube        True                  True
# 20  youtube        True                  True
# 21  youtube        True                  True
# 22  youtube        True                  True
# 23  youtube        True                  True
# 24  youtube        True                  True
# 25  youtube        True                  True
# 26  youtube        True                 False
# 27  youtube        True                  True
# 28  youtube        True                  True
# 29  youtube        True                  True
# 30  youtube        True                  True
# 31  youtube        True                  True
# 32  youtube        True                  True
# 33  youtube        True                  True
# 34  youtube        True                  True
# 35  youtube        True                  True
# 36  youtube        True                  True
# 37  youtube        True                  True
# 38  youtube        True                  True
# 39  youtube        True                  True
# 40  youtube        True                  True
# 41  youtube        True                  True
# 42  youtube        True                  True
# 43  youtube        True                  True
# 44  youtube        True                  True
#
# [45 rows x 25 columns]

# %%
#Load data
csv_buffer = StringIO()
df = pd.read_csv('youtube_metadata.csv')
df.to_csv(csv_buffer, index=False)

# %% [markdown]
# Create AWS account, create an s3 bucket called "electric-scooters"
# Create an API key and add details in the following

# %%
import boto3

# Upload to S3
client = boto3.client(
    's3',
    aws_access_key_id="",
    aws_secret_access_key="",
)
client.put_object(Bucket='electric-scooters', Key='youtube_metadata.csv', Body=csv_buffer.getvalue())

print("Data successfully uploaded to S3")
# Out:
# Data successfully uploaded to S3
